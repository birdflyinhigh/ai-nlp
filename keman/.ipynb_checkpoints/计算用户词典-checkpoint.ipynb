# %%
import requests

url = "http://172.17.51.34:5000/support/parse"
data = {
    'q': "当前，社会诚信体系建设深入人心，霸座等失信事件屡屡占据媒体头条，国家有关部门和一些地方政府陆续出台相关措施对失信行为予以惩戒。同样在6月3日，北京市交通委发布《关于对轨道交通不文明乘车行为记录个人信用不良信息的实施细则》，明确了对地铁霸座、进食等“严重违规者”的处罚细则。有不文明行为，且不听劝阻，拒绝下车、出站，扰乱轨道交通车站、车厢秩序且拒绝参与志愿服务的行为人，即日起将被记录个人信用不良记录。"
}

# %%
r = requests.get(url, params=data)
r.json()

# %%
import pandas as pd
df = pd.read_csv('content.csv')

# %%
df.columns = ['content']
words = df.content.tolist()

# %%
def get_api(word):
    data={
        "q": word
    }
    r = requests.get(url, params=data)
    return r.json()

# %%
for word in words:
    data = get_api(word)
    print(data)
    if word =="好评":
        break

# %%
f = open('./content.csv')
text = f.read()

# %%
f1 = open('./stopwords.txt')
stopwords = f1.readlines()

# %%
# coding=utf-8
import jieba
import re

from collections import Counter


class TextCutter(object):
    def __init__(self, stopwords):
        self.stop_word_list = stopwords
        self.zbj_word_list = []



    @staticmethod
    def get_word_list(filename):
        with open(filename, 'rb') as f:
            content = f.read().decode()
            words = content.splitlines()
            word_list = [w.strip() for w in words]
            return word_list

    def cut_text(self, text):

        words = jieba.cut(text, cut_all=False)
        counter = Counter()
        zbj_counter = Counter()
        for w in words:
            if w in self.stop_word_list:
                continue
            if w.isdigit():
                continue
            if len(w)<2:
                continue
            if w in self.zbj_word_list:
                zbj_counter[w] += 1
            counter[w] += 1

        print(counter.most_common())
        print(zbj_counter.most_common())

    def parse_phone(self):
        r = r"[0-9]+"
        phones = set(re.findall(r, self.text))
        print(phones)

# %%
cutter = TextCutter(stopwords=stopwords)

# %%
import requests
def get_api(word):
    url = "http://172.17.51.34:5000/support/parse"
    data={
        "q": word
    }
    r = requests.get(url, params=data)
    return r.json()
for word in words[100:200]:
    data = get_api(word)
    print(word)
    print(data['keywords'])
    print(data['participle'])
# Out:
# 很好，下次继续
# {'下次': 1, '很好': 1}
# ['很好', '下次']
# 满意
# {'满意': 1}
# ['满意']
# 非常细心，非常真诚，以后还要找你合作。
# {'细心': 1, '真诚': 1, '合作': 1}
# ['细心', '真诚', '找', '合作']
# good
# {'good': 1}
# ['good']
# 很好
# {'很好': 1}
# ['很好']
# 计件任务,稿件号：4602442合格!
# {'计件': 1, '4602442': 1, '稿件': 1, '合格': 1}
# ['计件', '稿件', '号', '4602442', '合格']
# 很不错的一个
# {'不错': 1}
# ['不错']
# 计件任务,稿件号：4559187合格!
# {'计件': 1, '4559187': 1, '稿件': 1, '合格': 1}
# ['计件', '稿件', '号', '4559187', '合格']
# 10
# {}
# []
# 计件任务,稿件号：4513254合格!
# {'计件': 1, '4513254': 1, '稿件': 1, '合格': 1}
# ['计件', '稿件', '号', '4513254', '合格']
# 计件任务,稿件号：4293417合格!
# {'计件': 1, '4293417': 1, '稿件': 1, '合格': 1}
# ['计件', '稿件', '号', '4293417', '合格']
# 计件任务,稿件号：4219407合格!
# {'计件': 1, '4219407': 1, '稿件': 1, '合格': 1}
# ['计件', '稿件', '号', '4219407', '合格']
# 设计的非常理想（格局合理，细节到位），服务态度也很好，尤其是时间观念超赞！
# {'超赞': 1, '服务态度': 1, '很好': 1, '到位': 1, '细节': 1, '观念': 1, '理想': 1, '格局': 1, '设计': 1}
# ['设计', '理想', '格局', '细节', '到位', '服务态度', '很好', '时间', '观念', '超赞']
# 评价方未及时做出评价,系统默认评价!
# {'评价': 3, '方未': 1, '默认': 1, '做出': 1, '系统': 1}
# ['评价', '方未', '做出', '评价', '系统', '默认', '评价']
# 计件任务,稿件号：4149687合格!
# {'计件': 1, '4149687': 1, '稿件': 1, '合格': 1}
# ['计件', '稿件', '号', '4149687', '合格']
# 付款及时
# {'付款': 1}
# ['付款']
# 合作非常愉快，可以长期合作。。
# {'合作': 2, '愉快': 1, '长期': 1}
# ['合作', '愉快', '长期', '合作']
# 非常愉快的一次交易，买家人很好，付款也很及时
# {'付款': 1, '买家': 1, '愉快': 1, '很好': 1, '交易': 1}
# ['愉快', '交易', '买家', '很好', '付款']
# 合作愉快～！
# {'合作愉快': 1}
# ['合作愉快']
# 非常负责的设计师，水平很高，设计的非常满意，速度也很快！极力推荐！
# 希望下次合作更加愉快！：）
# {'极力推荐': 1, '设计师': 1, '下次': 1, '愉快': 1, '满意': 1, '负责': 1, '很快': 1, '速度': 1, '设计': 2}
# ['负责', '设计师', '水平', '高', '设计', '满意', '速度', '很快', '极力推荐', '\r\n', '希望', '下次', '合作', '愉快']
# Maggie 谦虚，勤快，工作态度极其认真。选她没错！
# {'ag': 1, '勤快': 1, '谦虚': 1, '没错': 1, '态度': 1, '工作': 1}
# ['M', 'ag', 'g', ' ', '谦虚', '勤快', '工作', '态度', '选', '没错']
# 给力的买家,很痛快,欢迎下次光顾本店
# {'本店': 1, '给力': 1, '光顾': 1, '下次': 1, '买家': 1, '痛快': 1}
# ['给力', '买家', '痛快', '下次', '光顾', '本店']
# 花了不少精力沟通磨合，继续磨合吧，兼职的都是这样。卖家技术是 没问题，就是沟通比较麻烦
# {'磨合': 2, '沟通': 2, '都是': 1, '没问题': 1, '兼职': 1, '卖家': 1, '精力': 1, '麻烦': 1}
# ['花', '精力', '沟通', '磨合', '磨合', '兼职', '都是', '卖家', '技术', ' ', '没问题', '沟通', '麻烦']
# 谢谢您的赏识，最终圆满完成了本案。梦之队工作室，我们从2007年涉足互联网，从无人知晓到家喻户晓，期间辛酸自知。从无名小卒到运营第一，我们不骄傲，我们保持不断创新.梦之队，一群狼人，100%诚信度换您100%满意度。我们一直用心用实际行动回报客户，时刻准备着QQ1653311931 电话13938325984
# {'梦之队': 2, '0%': 2, '狼人': 1, '2007': 1, 'QQ1653311931': 1, '13938325984': 1, '无名小卒': 1, '诚信度': 1}
# ['谢谢您', '赏识', '最终', '圆满完成', '本案', '梦之队', '工作室', '2007', '涉足', '互联网', '无人知晓', '家喻户晓', '期间', '辛酸', '自知', '无名小卒', '运营', '第一', '骄傲', '不断创新', '梦之队', '一群', '狼人', '0%', '诚信度', '换', '0%', '满意度', '用心', '实际行动', '回报', '客户', '时刻', 'QQ1653311931', ' ', '电话', '13938325984']
# 当天就见效了，不错！这个很给力
# {'给力': 1, '见效': 1, '当天': 1, '不错': 1}
# ['当天', '见效', '不错', '给力']
# 很不错的卖家
# {'卖家': 1, '不错': 1}
# ['不错', '卖家']
# 我们画册的设计的比较满意，老板人也很好，后期修改了几次，最终达到满意的效果，谢谢！
# {'比较满意': 1, '画册': 1, '很好': 1, '谢谢': 1, '老板': 1, '满意': 2, '修改': 1, '几次': 1, '后期': 1, '效果': 1}
# ['画册', '设计', '比较满意', '老板', '很好', '后期', '修改', '几次', '最终', '满意', '效果', '谢谢']
# 性价比很高，很快就能在百度查询到
# {'能在': 1, '性价比': 1, '百度': 1, '查询': 1, '很快': 1}
# ['性价比', '高', '很快', '能在', '百度', '查询']
# 蛮好的，比之前买的那家便宜多了，态度服务都满意
# {'都满意': 1, '那家': 1, '便宜': 1, '态度': 1, '服务': 1}
# ['买', '那家', '便宜', '态度', '服务', '都满意']
# 好评!真不错!
# {'真不错': 1, '好评': 1}
# ['好评', '真不错']
# 很满意，雇主人很好，态度友好
# {'雇主': 1, '友好': 1, '很好': 1, '满意': 1, '态度': 1}
# ['满意', '雇主', '很好', '态度', '友好']
# 公司网站建设中合作最愉快的一次，特效十分好，设计很精美，多次调整是我们大家配合的结果，重要的是完成了老板托付。好评
# {'托付': 1, '特效': 1, '好评': 1, '精美': 1, '愉快': 1, '老板': 1, '网站': 1, '配合': 1, '设计': 1}
# ['公司', '网站', '建设', '中', '合作', '愉快', '特效', '设计', '精美', '调整', '配合', '老板', '托付', '好评']
# 好买家，合作愉快
# {'合作愉快': 1, '买家': 1}
# ['买家', '合作愉快']
# 技术比较专业，服务态度希望提高！
# {'服务态度': 1, '专业': 1, '希望': 1, '提高': 1, '技术': 1}
# ['技术', '专业', '服务态度', '希望', '提高']
# 雇主人很好，付款及时，沟通顺畅，期待下次合作！
# {'雇主': 1, '顺畅': 1, '付款': 1, '下次': 1, '很好': 1, '沟通': 1, '期待': 1, '合作': 1}
# ['雇主', '很好', '付款', '沟通', '顺畅', '期待', '下次', '合作']
# 沟通细致耐心，态度好
# {'细致': 1, '耐心': 1, '沟通': 1, '态度': 1}
# ['沟通', '细致', '耐心', '态度']
# 服务态度非常好，感觉很靠谱，下次还来！
# {'非常好': 1, '靠谱': 1, '服务态度': 1, '还来': 1, '下次': 1, '感觉': 1}
# ['服务态度', '非常好', '感觉', '靠谱', '下次', '还来']
# 沟通愉快  付款及时
# {'付款': 1, '愉快': 1, '沟通': 1}
# ['沟通', '愉快', ' ', ' ', '付款']
# 好评，期待下次合作，介绍朋友！
# {'好评': 1, '下次': 1, '期待': 1, '朋友': 1, '介绍': 1, '合作': 1}
# ['好评', '期待', '下次', '合作', '介绍', '朋友']
# 设计师非常耐心，持续了很长时间，一点都不嫌烦，设计出来的logo非常满意，这个价钱真的是超值，以后还会来
# {'嫌烦': 1, 'logo': 1, '还会来': 1, '超值': 1, '设计师': 1, '价钱': 1, '耐心': 1, '长时间': 1, '满意': 1}
# ['设计师', '耐心', '持续', '长时间', '一点', '嫌烦', '设计', 'logo', '满意', '价钱', '真的', '超值', '还会来']
# 有诚意需求明确
# {'诚意': 1, '需求': 1}
# ['诚意', '需求']
# 设计的我满意
# {'满意': 1, '设计': 1}
# ['设计', '满意']
# 亲爱的客户，您好！感谢您购买我们的服务。亲是个非常不错的雇主！
# 若有任何问题，请您立即与我们的客服进行联系。我们一定会与您满意。
# 期待您再次与我们联系。并与您的好友分享我们的服务！
# 在您的支持与鼓励下。我们将提供更优秀、更专业的服务！衷心致谢！
# {'服务': 3, '亲爱的': 1, '是个': 1, '一定会': 1, '您满意': 1, '致谢': 1, '衷心': 1}
# ['亲爱的', '客户', '您好', '购买', '服务', '亲', '是个', '不错', '雇主', '\r\n', '若有', '请', '客服', '一定会', '您满意', '\r\n', '期待', '好友', '分享', '服务', '\r\n', '支持', '鼓励', '提供', '优秀', '专业', '服务', '衷心', '致谢']
# 天泽推广 谢谢亲的光临和照顾。如果感觉我家效果做的还满意 ，还有需要的话，可以随时联系我哦。老客户有优惠的。业务QQ 806345 微信号 806345 欢迎骚扰
# {'806345': 2, '天泽': 1, 'QQ': 1, '微信号': 1, '需要的话': 1, '老客户': 1, '光临': 1, '骚扰': 1, '谢谢': 1, '我家': 1}
# ['天泽', '推广', ' ', '谢谢', '亲', '光临', '照顾', '感觉', '我家', '效果', '做', '满意', ' ', '需要的话', '老客户', '优惠', '业务', 'QQ', ' ', '806345', ' ', '微信号', ' ', '806345', ' ', '骚扰']
# 稿件质量不错，买家效率真高，很满意，服务态度没的说，希望以后继续合作。
# {'真高': 1, '服务态度': 1, '稿件': 1, '买家': 1, '效率': 1, '满意': 1, '不错': 1, '质量': 1, '合作': 1, '希望': 1}
# ['稿件', '质量', '不错', '买家', '效率', '真高', '满意', '服务态度', '说', '希望', '合作']
# 合作愉快，期待下次合作
# {'合作愉快': 1, '下次': 1, '期待': 1, '合作': 2}
# ['合作愉快', '期待', '下次', '合作']
# 此公司的设计比较有创意，风格不错，能理解客户的需求，是不错的选择。
# {'不错': 2, '创意': 1, '客户': 1, '理解': 1, '风格': 1, '设计': 1, '需求': 1, '选择': 1, '公司': 1}
# ['公司', '设计', '创意', '风格', '不错', '理解', '客户', '需求', '不错', '选择']
# 很好的雇主，期待下次合作
# {'雇主': 1, '下次': 1, '期待': 1, '合作': 1}
# ['雇主', '期待', '下次', '合作']
# 谢谢谢谢谢谢谢谢谢谢
# {'谢谢': 5}
# ['谢谢', '谢谢', '谢谢', '谢谢', '谢谢']
# 非常好的买家，非常感谢。
# {'非常感谢': 1, '买家': 1}
# ['买家', '非常感谢']
# 好！
# {}
# []
# 前后修改了很多次，一直很耐心的帮我改，而且再打款之后还能继续帮我改，谢谢~
# {'帮我': 2, '打款': 1, '耐心': 1, '谢谢': 1, '修改': 1}
# ['修改', '耐心', '帮我', '改', '打款', '帮我', '改', '谢谢']
# 服务态度很好，每天流量也很准，地区和时间也都恰到好处！
# {'服务态度': 1, '很准': 1, '恰到好处': 1, '很好': 1, '流量': 1, '地区': 1, '时间': 1}
# ['服务态度', '很好', '流量', '很准', '地区', '时间', '恰到好处']
# 不错，给个好评！
# {'好评': 1, '不错': 1}
# ['不错', '好评']
# 感谢您的信赖，子中策划主营网络推广，公关维护，网店推广，爆款打造，软文写作，如有需要欢迎加QQ2481482122为您服务
# {'软文': 1, '推广': 2, '子中': 1, '爆款': 1, 'QQ2481482122': 1, '公关': 1, '网店': 1, '信赖': 1}
# ['信赖', '子中', '策划', '主营', '网络', '推广', '公关', '维护', '网店', '推广', '爆款', '打造', '软文', '写作', '如有', '加', 'QQ2481482122']
# 非常好的雇主
# {'雇主': 1}
# ['雇主']
# 不错，有效果！下次还来。
# {'还来': 1, '下次': 1, '不错': 1, '效果': 1}
# ['不错', '效果', '下次', '还来']
# 还可以，给个好评
# {'还可以': 1, '好评': 1}
# ['还可以', '好评']
# 确实不错，没有让我们失望，沟通及时，设计水平高，以后长期合作。
# {'失望': 1, '沟通': 1, '不错': 1, '确实': 1, '设计': 1, '合作': 1, '长期': 1, '水平': 1}
# ['确实', '不错', '失望', '沟通', '设计', '水平', '高', '长期', '合作']
# 一如既往的好雇主～希望一直合作！！
# {'雇主': 1, '一如既往': 1, '合作': 1, '希望': 1}
# ['一如既往', '雇主', '希望', '合作']
# 欢迎下次光临新视觉推广旗舰店
# {'新视觉': 1, '旗舰店': 1, '光临': 1, '下次': 1, '推广': 1}
# ['下次', '光临', '新视觉', '推广', '旗舰店']
# 谢谢合作！希望下次继续找我们闪电章鱼推广，淘宝推广，微信推广，贴吧推广，短信营销，微博推广，淘宝销量,收藏，流量，购物车一站式解决,
# {'推广': 5, '淘宝': 2, '谢谢合作': 1, '微信': 1, '贴吧': 1, '微博': 1, '购物车': 1, '章鱼': 1, '一站式': 1, '短信': 1}
# ['谢谢合作', '希望', '下次', '找', '闪电', '章鱼', '推广', '淘宝', '推广', '微信', '推广', '贴吧', '推广', '短信', '营销', '微博', '推广', '淘宝', '销量', '收藏', '流量', '购物车', '一站式', '解决']
# 雇主不错付款及时，希望下次继续合作 (思考设计：http://shop.zbj.com/5140335/)
# {'http': 1, 'shop': 1, 'zbj': 1, '5140335': 1, '雇主': 1, '付款': 1, '下次': 1, '思考': 1, '不错': 1}
# ['雇主', '不错', '付款', '希望', '下次', '合作', ' ', '思考', '设计', 'http', 'shop', 'zbj', '5140335']
# 专业，服务好，周到！
# {'服务好': 1, '周到': 1, '专业': 1}
# ['专业', '服务好', '周到']
# 初次合作非常好。很专业！
# {'非常好': 1, '初次': 1, '专业': 1, '合作': 1}
# ['初次', '合作', '非常好', '专业']
# 非常好的雇主，值得信赖
# {'雇主': 1, '信赖': 1, '值得': 1}
# ['雇主', '值得', '信赖']
# 欢迎选择艺点，期待我们的再次合作，有问题随时找我，qq2850279675
# {'艺点': 1, 'qq': 1, '2850279675': 1, '期待': 1, '合作': 1, '选择': 1}
# ['选择', '艺点', '期待', '合作', '找', 'qq', '2850279675']
# 听说武汉发洪水还这么拼，赞一个
# {'洪水': 1, '武汉': 1, '听说': 1}
# ['听说', '武汉', '发', '洪水', '拼', '赞']
# 软文质量很好，多次合作，辛苦了
# {'软文': 1, '辛苦': 1, '很好': 1, '质量': 1, '合作': 1}
# ['软文', '质量', '很好', '合作', '辛苦']
# 非常感谢您的支持与信任
# {'信任': 1, '支持': 1}
# ['支持', '信任']
# 您好，感谢您的评价，合美飞扬将以最热情专业的态度为您服务
# {'合美': 1, '飞扬': 1, '您好': 1, '评价': 1, '热情': 1, '专业': 1, '态度': 1}
# ['您好', '评价', '合美', '飞扬', '热情', '专业', '态度']
# 合作愉快，很好，下次在合作
# {'合作愉快': 1, '下次': 1, '很好': 1, '合作': 2}
# ['合作愉快', '很好', '下次', '合作']
# 有机会 下次继续合作
# {'下次': 1, '合作': 1, '机会': 1}
# ['机会', ' ', '下次', '合作']
# 合作很好！！！！！！！！！！！下次再找你们家。
# {'下次': 1, '很好': 1, '合作': 1}
# ['合作', '很好', '下次', '找', '家']
# 谢谢你的支持，蜘蛛客优化会为你做得更好！
# {'你做': 1, '会为': 1, '蜘蛛': 1, '谢谢': 1, '优化': 1, '更好': 1, '支持': 1}
# ['谢谢', '支持', '蜘蛛', '客', '优化', '会为', '你做', '更好']
# 服务挺好的。
# {'服务': 1}
# ['服务', '挺']
# 合作愉快
# {'合作愉快': 1}
# ['合作愉快']
# 我号被盗了  把钱还给我
# {'被盗': 1, '还给': 1}
# ['号', '被盗', ' ', ' ', '钱', '还给']
# 挺有耐心的。服务态度很好！
# {'服务态度': 1, '耐心': 1, '很好': 1}
# ['挺', '耐心', '服务态度', '很好']
# 很好的雇主，期待下次合作~
# {'雇主': 1, '下次': 1, '期待': 1, '合作': 1}
# ['雇主', '期待', '下次', '合作']
# 第二次合作了，效率存货杠杠的！！下次继续
# {'杠杠': 1, '下次': 1, '存货': 1, '效率': 1, '第二次': 1, '合作': 1}
# ['第二次', '合作', '效率', '存货', '杠杠', '下次']
# 好雇主好雇主
# {'雇主': 2}
# ['雇主', '雇主']
# 非常好的创意，设计师也很耐心反复修改，最终效果非常满意。
# {'设计师': 1, '创意': 1, '耐心': 1, '满意': 1, '修改': 1, '反复': 1, '效果': 1, '最终': 1}
# ['创意', '设计师', '耐心', '反复', '修改', '最终', '效果', '满意']
# 期待下次继续合作
# {'下次': 1, '期待': 1, '合作': 1}
# ['期待', '下次', '合作']
# 一次很满意的合作！
# {'满意': 1, '合作': 1}
# ['满意', '合作']
# 客户人很好，谢谢您的支持和认可，以诚为本，诚信做事，我们会一如既往认真为您服务，祝您生活愉快！！！
# {'以诚': 1, '为本': 1, '谢谢您': 1, '一如既往': 1, '诚信': 1, '做事': 1, '愉快': 1, '很好': 1}
# ['客户', '很好', '谢谢您', '支持', '认可', '以诚', '为本', '诚信', '做事', '一如既往', '生活', '愉快']
# 合作愉快。。谢谢
# {'合作愉快': 1, '谢谢': 1}
# ['合作愉快', '谢谢']
# 很愉快的合作。。。
# {'愉快': 1, '合作': 1}
# ['愉快', '合作']
# 满意满意满意满意满意满意满意满意满意满意满意满意满意满意满意满意满意满意满意满意满意满意满意满意满意满意满意满意满意满意满意满意满意满意满意满意
# {'满意': 36}
# ['满意', '满意', '满意', '满意', '满意', '满意', '满意', '满意', '满意', '满意', '满意', '满意', '满意', '满意', '满意', '满意', '满意', '满意', '满意', '满意', '满意', '满意', '满意', '满意', '满意', '满意', '满意', '满意', '满意', '满意', '满意', '满意', '满意', '满意', '满意', '满意']
# 要求明确 付款及时
# {'付款': 1}
# [' ', '付款']
# 没说的，特别棒！在这里就是放心！
# {'没说的': 1, '放心': 1, '特别': 1}
# ['没说的', '特别', '棒', '放心']
# 欢迎下次 再来
# {'下次': 1, '再来': 1}
# ['下次', ' ', '再来']
# 设计师素质好，动脑筋，发挥了创意，美感好，对设计说明有理解力，在沟通中耐心、细心，认真负责，很满意
# {'设计说明': 1, '认真负责': 1, '理解力': 1, '动脑筋': 1, '美感': 1, '设计师': 1, '细心': 1, '创意': 1, '素质': 1, '耐心': 1}
# ['设计师', '素质', '动脑筋', '发挥', '创意', '美感', '设计说明', '理解力', '沟通', '中', '耐心', '细心', '认真负责', '满意']
# 交给宫一完全放心，质量好，有耐心，已经多次合作了
# {'宫一': 1, '质量好': 1, '耐心': 1, '交给': 1, '放心': 1, '合作': 1}
# ['交给', '宫一', '放心', '质量好', '耐心', '合作']
# 不错，。。。。
# {'不错': 1}
# ['不错']
# 感谢您对动点在线的支持，动点在线一如既往的为你提供优质的网络在线推广服务。我们主要提供新媒体营销、文案策划、广告投放等服务。
# {'在线': 3, '对动点': 1, '动点': 2, '新媒体': 1, '广告投放': 1, '服务': 2, '文案': 1, '提供': 2, '一如既往': 1}
# ['对动点', '在线', '支持', '动点', '在线', '一如既往', '提供', '优质', '网络', '在线', '推广', '服务', '提供', '新媒体', '营销', '文案', '策划', '广告投放', '服务']
# 一点效果也没有，白白浪费钱了
# {'白白浪费': 1, '效果': 1, '一点': 1}
# ['一点', '效果', '白白浪费', '钱']
# 很专业的客户。
# {'专业': 1, '客户': 1}
# ['专业', '客户']
# 合作愉快，顺利完成，希望能继续合作!
# {'合作愉快': 1, '顺利完成': 1, '合作': 2, '希望': 1}
# ['合作愉快', '顺利完成', '希望', '合作']
# 很愉快的合作经历
# {'愉快': 1, '经历': 1, '合作': 1}
# ['愉快', '合作', '经历']
